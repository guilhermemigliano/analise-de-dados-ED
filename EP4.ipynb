# %% [markdown]
# Importando os dados e bibliotecas utilizados

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv(r'escolas.CSV',
                delimiter = '|',
                encoding = 'iso-8859-1')

# %% [markdown]
# **Número de escolas por estado que possuem abastecimento de água**
# --------------------

# %%
df.query('IN_AGUA_INEXISTENTE == 0')['CO_UF'].value_counts().plot(kind='bar', figsize=(20,10), fontsize = 'x-large')
plt.title('ESCOLAS NO BRASIL COM ABASTECIMENTO DE AGUA')
plt.ylabel('QUANTIDADE')
plt.xlabel('ESTADOS')
plt.grid(True, which='major')

# %% [markdown]
# **Número de escolas por estado que não possuem abastecimento de água**
# --------------------

# %%
df.query('IN_AGUA_INEXISTENTE == 1')['CO_UF'].value_counts().plot(kind='bar', figsize=(20,10), fontsize = 'x-large')
plt.title('ESCOLAS NO BRASIL COM ABASTECIMENTO DE AGUA INEXISTENTE')
plt.ylabel('QUANTIDADE')
plt.xlabel('ESTADOS')
plt.grid(True, which='major')

# %% [markdown]
# **Número de escolas por estado que possuem fornecimento de energia elétrica**
# --------------------

# %%
df.query('IN_ENERGIA_INEXISTENTE == 0')['CO_UF'].value_counts().plot(kind='bar', figsize=(20,10), fontsize = 'x-large')
plt.title('ESCOLAS NO BRASIL COM FORNECIMENTO DE ENERGIA')
plt.ylabel('QUANTIDADE')
plt.xlabel('ESTADOS')
plt.grid(True, which='major')

# %% [markdown]
# **Número de escolas por estado que não possuem fornecimento de energia elétrica**
# --------------------

# %%
df.query('IN_ENERGIA_INEXISTENTE == 1')['CO_UF'].value_counts().plot(kind='bar', figsize=(20,10), fontsize = 'x-large')
plt.title('ESCOLAS NO BRASIL COM FORNECIMENTO DE ENERGIA INEXISTENTE')
plt.ylabel('QUANTIDADE')
plt.xlabel('ESTADOS')
plt.grid(True, which='major')

# %% [markdown]
# **Número de escolas por estado que não possuem tratamento de esgoto**
# --------------------

# %%
df.query('IN_ESGOTO_INEXISTENTE == 0')['CO_UF'].value_counts().plot(kind='bar', figsize=(20,10), fontsize = 'x-large')
plt.title('ESCOLAS NO BRASIL COM TRATAMENTO DE ESGOTO')
plt.ylabel('QUANTIDADE')
plt.xlabel('ESTADOS')
plt.grid(True, which='major')

# %% [markdown]
# **Número de escolas por estado que não possuem tratamento de esgoto**
# --------------------

# %%
df.query('IN_ESGOTO_INEXISTENTE == 1')['CO_UF'].value_counts().plot(kind='bar', figsize=(20,10), fontsize = 'x-large')
plt.title('ESCOLAS NO BRASIL COM TRATAMENTO DE ESGOTO INEXISTENTE')
plt.ylabel('QUANTIDADE')
plt.xlabel('ESTADOS')
plt.grid(True, which='major')

# %% [markdown]
# **Número de escolas por estado que possuem condições básicas de funcionamento (Água, energia elétrica e tratamento de esgoto)**
# --------------------

# %%
df.query('IN_AGUA_INEXISTENTE == 0 and IN_ENERGIA_INEXISTENTE == 0 and IN_ESGOTO_INEXISTENTE == 0')['CO_UF'].value_counts().plot(kind='bar', figsize=(20,10), fontsize = 'x-large')
plt.title('ESCOLAS NO BRASIL QUE POSSUEM CONDIÇOES BASICAS DE FUNCIONAMENTO')
plt.ylabel('QUANTIDADE')
plt.xlabel('ESTADOS')
plt.grid(True, which='major')

# %% [markdown]
# **Número de escolas por estado que não possuem condições básicas de funcionamento (Água, energia elétrica e tratamento de esgoto)**
# --------------------

# %%
df.query('IN_AGUA_INEXISTENTE == 1 and IN_ENERGIA_INEXISTENTE == 1 and IN_ESGOTO_INEXISTENTE == 1')['CO_UF'].value_counts().plot(kind='bar', figsize=(20,10), fontsize = 'x-large')
plt.title('ESCOLAS NO BRASIL QUE NAO POSSUEM CONDIÇOES BASICAS DE FUNCIONAMENTO')
plt.ylabel('QUANTIDADE')
plt.xlabel('ESTADOS')
plt.grid(True, which='major')
